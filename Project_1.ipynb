# %% [markdown]
# # <div align="center"> AtliQo Bank Credit Card Launch: Phase 1

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
df_cust = pd.read_csv("C:\codes\chapter8_assets\chapter8_assets\dataset\customers.csv")
df_cust.head()
# Out:
#    cust_id          name  gender  age location      occupation  annual_income  \
# 0        1  Dhruv Bansal  Female    2     City  Business Owner       358211.0
# 1        2  Kabir Thakur  Female   47     City      Consultant        65172.0
# 2        3  Kriti Mangal    Male   21     City      Freelancer        22378.0
# 3        4  Sara Dwivedi    Male   24    Rural      Freelancer        33563.0
# 4        5   Aarohi Negi    Male   48     City      Consultant        39406.0
#
#   marital_status
# 0        Married
# 1         Single
# 2        Married
# 3        Married
# 4        Married

# %%
df_trans = pd.read_csv(r"C:\codes\chapter8_assets\chapter8_assets\dataset\transactions.csv") #"r" - "Raw"
df_trans.head()
# Out:
#    tran_id  cust_id   tran_date  tran_amount  platform   product_category  \
# 0        1      705  2023-01-01           63  Flipkart        Electronics
# 1        2      385  2023-01-01           99   Alibaba  Fashion & Apparel
# 2        3      924  2023-01-01          471   Shopify             Sports
# 3        4      797  2023-01-01           33   Shopify  Fashion & Apparel
# 4        5      482  2023-01-01           68    Amazon  Fashion & Apparel
#
#   payment_type
# 0      Phonepe
# 1  Credit Card
# 2      Phonepe
# 3         Gpay
# 4  Net Banking

# %%
df_cs = pd.read_csv(r"C:\codes\chapter8_assets\chapter8_assets\dataset\credit_profiles.csv")
df_cs.head()
# Out:
#    cust_id  credit_score  credit_utilisation  outstanding_debt  \
# 0        1           749            0.585171           19571.0
# 1        2           587            0.107928          161644.0
# 2        3           544            0.854807             513.0
# 3        4           504            0.336938             224.0
# 4        5           708            0.586151           18090.0
#
#    credit_inquiries_last_6_months  credit_limit
# 0                             0.0       40000.0
# 1                             2.0        1250.0
# 2                             4.0        1000.0
# 3                             2.0        1000.0
# 4                             2.0       40000.0

# %%
df_cust.describe()
# Out:
#            cust_id          age  annual_income
# count  1000.000000  1000.000000     950.000000
# mean    500.500000    36.405000  139410.314737
# std     288.819436    15.666155  112416.802007
# min       1.000000     1.000000       2.000000
# 25%     250.750000    26.000000   47627.500000
# 50%     500.500000    32.000000  112218.500000
# 75%     750.250000    46.000000  193137.500000
# max    1000.000000   135.000000  449346.000000

# %% [markdown]
# Annual_Income and age min is 2 and 1. This are the error to be fixed.

# %%
df_cust.isnull().sum()
# Out:
# cust_id            0
# name               0
# gender             0
# age                0
# location           0
# occupation         0
# annual_income     50
# marital_status     0
# dtype: int64

# %% [markdown]
# 50 - Null valve of annual icome

# %%
df_cust[df_cust.annual_income.isnull()].head()
# Out:
#      cust_id             name  gender  age location           occupation  \
# 14        15       Isha Arora  Female   25    Rural               Artist
# 82        83  Sanjana Singhal    Male   27     City           Freelancer
# 97        98        Sia Batra    Male   47   Suburb       Business Owner
# 102      103    Pooja Ganguly    Male   32     City       Data Scientist
# 155      156  Krishna Trivedi    Male   24     City  Fullstack Developer
#
#      annual_income marital_status
# 14             NaN        Married
# 82             NaN         Single
# 97             NaN        Married
# 102            NaN        Married
# 155            NaN        Married

# %%
df_cust.annual_income.mean(), df_cust.annual_income.median()
# Out:
# (139410.31473684212, 112218.5)

# %% [markdown]
# Now find median based on the occupation, Mean cant be used due to data points have error like 2 or null in annual_income.

# %% [markdown]
# ### we can now replace median valve by occupation.

# %%
occupation_wise_inc_median = df_cust.groupby("occupation")["annual_income"].median()
occupation_wise_inc_median
# Out:
# occupation
# Accountant              65265.0
# Artist                  45794.0
# Business Owner         261191.5
# Consultant              58017.0
# Data Scientist         135759.0
# Freelancer              46759.0
# Fullstack Developer     76774.0
# Name: annual_income, dtype: float64

# %%
occupation_wise_inc_median["Fullstack Developer"]
# Out:
# 76774.0

# %%
occupation_wise_inc_median["Business Owner"]
# Out:
# 261191.5

# %% [markdown]
# Now replace this null valve to median by thier occupation.

# %%
def get_median_val(row):
    if pd.isnull (row["annual_income"]):
        return occupation_wise_inc_median[row["occupation"]]
    else:
        return row["annual_income"]

# %%
df_cust.iloc[14]
# Out:
# cust_id                   15
# name              Isha Arora
# gender                Female
# age                       25
# location               Rural
# occupation            Artist
# annual_income            NaN
# marital_status       Married
# Name: 14, dtype: object

# %%
df_cust["annual_income"]  = df_cust.apply( 
    lambda row : occupation_wise_inc_median[row["occupation"]] if pd.isnull (row["annual_income"]) else row["annual_income"] , axis=1)

# %%
df_cust.iloc[14]
# Out:
# cust_id                   15
# name              Isha Arora
# gender                Female
# age                       25
# location               Rural
# occupation            Artist
# annual_income        45794.0
# marital_status       Married
# Name: 14, dtype: object

# %%
occupation_wise_inc_median["Artist"]
# Out:
# 45794.0

# %% [markdown]
# Now that the median is apply to the null valve to all based on their occpuation_income_wise_median. Check the distridution of annual income

# %%
plt.figure(figsize=(5,5))
sns.histplot(df_cust["annual_income"],kde=True,color="green",label="Data")
plt.xlabel("Histogram of annual_income")
plt.show()

# %% [markdown]
# As expected it is right skewed. now checking for outliers.

# %%
df_cust.describe()
# Out:
#            cust_id          age  annual_income
# count  1000.000000  1000.000000     950.000000
# mean    500.500000    36.405000  139410.314737
# std     288.819436    15.666155  112416.802007
# min       1.000000     1.000000       2.000000
# 25%     250.750000    26.000000   47627.500000
# 50%     500.500000    32.000000  112218.500000
# 75%     750.250000    46.000000  193137.500000
# max    1000.000000   135.000000  449346.000000

# %% [markdown]
# Now mentioned in the problem statement that minium annual_income is 100.

# %%
df_cust[df_cust.annual_income<100]
# Out:
#      cust_id             name  gender  age location           occupation  \
# 31        32     Veer Gambhir    Male   50     City       Business Owner
# 262      263      Veer Rathod    Male   53   Suburb       Business Owner
# 316      317  Avinash Chauhan    Male   47     City           Consultant
# 333      334  Samaira D'Souza  Female   29     City       Data Scientist
# 340      341    Ridhi Rastogi  Female   33    Rural  Fullstack Developer
# 543      544      Gauri Gupta    Male   54     City           Consultant
# 592      593     Vivaan Pande  Female   32     City       Business Owner
# 633      634   Aradhya Pandey    Male   26     City       Data Scientist
# 686      687      Gauri Nanda    Male   40     City       Business Owner
# 696      697    Avani Lalwani    Male   47     City           Consultant
#
#      annual_income marital_status
# 31            50.0        Married
# 262           50.0        Married
# 316           50.0        Married
# 333           50.0        Married
# 340           50.0        Married
# 543            2.0        Married
# 592           50.0        Married
# 633            2.0        Married
# 686            2.0        Married
# 696           20.0        Married

# %%
for index, row in df_cust.iterrows():
    if row["annual_income"]<100:
        df_cust.at[index, "annual_income"] = occupation_wise_inc_median[row["occupation"]]

# %%
df_cust[df_cust.annual_income<100]
# Out:
# Empty DataFrame
# Columns: [cust_id, name, gender, age, location, occupation, annual_income, marital_status]
# Index: []

# %% [markdown]
# now the annual_income"s are higher that 100.

# %%
avg_inc_per_occupation = df_cust.groupby("occupation")["annual_income"].mean()
avg_inc_per_occupation
# Out:
# occupation
# Accountant              64123.562500
# Artist                  45267.685714
# Business Owner         268734.471223
# Consultant              60944.606742
# Data Scientist         137149.760479
# Freelancer              76990.479821
# Fullstack Developer     78810.535211
# Name: annual_income, dtype: float64

# %%
avg_inc_per_occupation.index
# Out:
# Index(['Accountant', 'Artist', 'Business Owner', 'Consultant',
#        'Data Scientist', 'Freelancer', 'Fullstack Developer'],
#       dtype='object', name='occupation')

# %%
avg_inc_per_occupation.values
# Out:
# array([ 64123.5625    ,  45267.68571429, 268734.47122302,  60944.60674157,
#        137149.76047904,  76990.47982063,  78810.53521127])

# %%
sns.barplot(x=avg_inc_per_occupation.index,y=avg_inc_per_occupation.values, palette='tab20' )
plt.xticks(rotation=45)
plt.title('Average Annual Income Per Occupation')
plt.xlabel('Occupation')
plt.ylabel('Average Annual Income ($)')
plt.show()

# %% [markdown]
# now using ai for different categoreies.

# %%
# List of categorical columns
categorical_columns = ['gender', 'location', 'occupation', 'marital_status']

# Loop through each categorical column and plot a bar chart of average annual income
for col in categorical_columns:
    plt.figure(figsize=(8, 4))
    avg_income_per_group = df_cust.groupby(col)['annual_income'].mean().sort_values()
    sns.barplot(x=avg_income_per_group.index, y=avg_income_per_group.values, palette='tab10')
    plt.xticks(rotation=45)
    plt.title(f'Average Annual Income Per {col.capitalize()}')
    plt.xlabel(col.capitalize())
    plt.ylabel('Average Annual Income ($)')
    plt.show()

# %%
# List of categorical columns
cat_cols = ['gender', 'location', 'occupation', 'marital_status']

num_rows = 2
# Create subplots
fig, axes = plt.subplots(num_rows, 2, figsize=(12, 4 * num_rows))

# Flatten the axes array to make it easier to iterate
axes = axes.flatten()

# Create subplots for each categorical column
for i, cat_col in enumerate(cat_cols):
    # Calculate the average annual income for each category
    avg_income_by_category = df_cust.groupby(cat_col)['annual_income'].mean().reset_index()
    
    # Sort the data by 'annual_income' before plotting
    sorted_data = avg_income_by_category.sort_values(by='annual_income', ascending=False)
    
    sns.barplot(x=cat_col, y='annual_income', data=sorted_data, ci=None, ax=axes[i], palette='tab10')
    axes[i].set_title(f'Average Annual Income by {cat_col}')
    axes[i].set_xlabel(cat_col)
    axes[i].set_ylabel('Average Annual Income')

    # Rotate x-axis labels for better readability
    axes[i].set_xticklabels(axes[i].get_xticklabels(), rotation=45)

# Hide any unused subplots
for i in range(len(cat_cols), len(axes)):
    fig.delaxes(axes[i])
plt.tight_layout()
plt.show()

# %% [markdown]
# Age Analysis

# %%
df_cust.describe()
# Out:
#            cust_id          age  annual_income
# count  1000.000000  1000.000000    1000.000000
# mean    500.500000    36.405000  140483.548500
# std     288.819436    15.666155  110463.002934
# min       1.000000     1.000000    5175.000000
# 25%     250.750000    26.000000   49620.500000
# 50%     500.500000    32.000000  115328.000000
# 75%     750.250000    46.000000  195514.250000
# max    1000.000000   135.000000  449346.000000

# %% [markdown]
# Age has error like min 1 , outlies like max 135. which is not good.

# %%
df_cust.age.isnull().sum() ## none of them is null
# Out:
# 0

# %%
min_age =df_cust.age.min()
max_age = df_cust.age.max() 
min_age , max_age
# Out:
# (1, 135)

# %%
plt.hist(df_cust.age, bins=20, edgecolor='black')
plt.xlabel("Age")
plt.ylabel("Count")
plt.title("Customer Age Distribution")

plt.axvline(min_age, color="red", label=f"Min Age: {min_age}")
plt.axvline(max_age, color="yellow", label=f"Max Age: {max_age}")

plt.legend()
plt.show()

# %%
median_age_per_occupation = df_cust.groupby('occupation')['age'].median()
median_age_per_occupation
# Out:
# occupation
# Accountant             31.5
# Artist                 26.0
# Business Owner         51.0
# Consultant             46.0
# Data Scientist         32.0
# Freelancer             24.0
# Fullstack Developer    27.5
# Name: age, dtype: float64

# %%
df_cust[(df_cust.age<15)|(df_cust.age>80)] ## as mentioned in the problem statement.
# Out:
#      cust_id              name  gender  age location           occupation  \
# 0          1      Dhruv Bansal  Female    2     City       Business Owner
# 41        42      Manya Thakur    Male  110     City               Artist
# 165      166     Swara Mehtani  Female    1     City           Freelancer
# 174      175     Sneha Jaiswal    Male  110     City           Freelancer
# 222      223      Aaryan Bajaj    Male  110   Suburb           Freelancer
# 277      278      Amaira Dewan    Male  110     City           Consultant
# 295      296        Veer Anand    Male    1    Rural           Accountant
# 325      326   Yash Chatterjee    Male  110     City           Accountant
# 610      611     Advait Mangal    Male  135    Rural       Business Owner
# 692      693      Aarohi Dubey    Male    1     City       Business Owner
# 703      704   Aradhya Goswami  Female  110     City           Freelancer
# 709      710       Rehan Patel  Female  110     City       Data Scientist
# 728      729    Yuvraj Gambhir    Male  135     City       Business Owner
# 832      833    Pranav Dwivedi  Female  110     City  Fullstack Developer
# 845      846       Anika Kadam    Male    1     City           Consultant
# 855      856     Aarav D'Souza  Female    2     City  Fullstack Developer
# 895      896       Ritvik Soni    Male    1     City           Freelancer
# 923      924       Kriti Joshi    Male  110     City           Freelancer
# 951      952      Ishan Khanna    Male  135     City       Data Scientist
# 991      992  Krishna Banerjee    Male  135     City  Fullstack Developer
#
#      annual_income marital_status
# 0         358211.0        Married
# 41          7621.0        Married
# 165        39721.0         Single
# 174        23723.0        Married
# 222       210987.0        Married
# 277        96522.0         Single
# 295        55254.0        Married
# 325        61021.0         Single
# 610       444776.0        Married
# 692        83045.0        Married
# 703        43404.0         Single
# 709        98417.0        Married
# 728       382836.0        Married
# 832        95379.0         Single
# 845        20838.0        Married
# 855        30689.0        Married
# 895        31533.0        Married
# 923        51629.0        Married
# 951        49677.0        Married
# 991        93267.0         Single

# %%
outliers = df_cust[(df_cust.age<15)|(df_cust.age>80)]
outliers.shape
# Out:
# (20, 8)

# %%
df_cust.age.median()
# Out:
# 32.0

# %%
for index, row in outliers.iterrows():
    if pd.notnull(row['age']):
        occupation = df_cust.at[index, 'occupation']
        df_cust.at[index, 'age'] = median_age_per_occupation[occupation]

# %%
df_cust[(df_cust.age<15)|(df_cust.age>80)]
# Out:
# Empty DataFrame
# Columns: [cust_id, name, gender, age, location, occupation, annual_income, marital_status]
# Index: []

# %% [markdown]
# Now the age outliers are taken care of.

# %%
df_cust.head()
# Out:
#    cust_id          name  gender   age location      occupation  \
# 0        1  Dhruv Bansal  Female  51.0     City  Business Owner
# 1        2  Kabir Thakur  Female  47.0     City      Consultant
# 2        3  Kriti Mangal    Male  21.0     City      Freelancer
# 3        4  Sara Dwivedi    Male  24.0    Rural      Freelancer
# 4        5   Aarohi Negi    Male  48.0     City      Consultant
#
#    annual_income marital_status
# 0       358211.0        Married
# 1        65172.0         Single
# 2        22378.0        Married
# 3        33563.0        Married
# 4        39406.0        Married

# %%
df_cust.age.describe()
# Out:
# count    1000.000000
# mean       35.541500
# std        12.276634
# min        18.000000
# 25%        26.000000
# 50%        32.000000
# 75%        44.250000
# max        64.000000
# Name: age, dtype: float64

# %% [markdown]
# ### Data Visualization: Age Column

# %% [markdown]
# Now giving the above info to ai, visualization of age in PI. creates a bin of ages.

# %%
# Define the bin edges and labels
bin_edges = [17, 25, 48, 65]  # Adjust as needed
bin_labels = ['18-25', '26-48', '49-65']

# Use the cut function to bin and label the age column
pd.cut(df_cust['age'], bins=bin_edges, labels=bin_labels)
# Out:
# 0      49-65
# 1      26-48
# 2      18-25
# 3      18-25
# 4      26-48
#        ...
# 995    26-48
# 996    49-65
# 997    26-48
# 998    26-48
# 999    26-48
# Name: age, Length: 1000, dtype: category
# Categories (3, object): ['18-25' < '26-48' < '49-65']

# %%
# Define the bin edges and labels
bin_edges = [17, 25, 48, 65]  # Adjust as needed
bin_labels = ['18-25', '26-48', '49-65']

# Use the cut function to bin and label the age column
df_cust['age_group'] = pd.cut(df_cust['age'], bins=bin_edges, labels=bin_labels)

# %%
df_cust['age_group'].value_counts(normalize=True)*100
# Out:
# age_group
# 26-48    56.7
# 18-25    24.6
# 49-65    18.7
# Name: proportion, dtype: float64

# %%
# Calculate the count of values in each age group
age_group_counts = df_cust['age_group'].value_counts(normalize=True) * 100

# Plot the pie chart
plt.figure(figsize=(4, 4))
plt.pie(
    age_group_counts, 
    labels=age_group_counts.index, 
    explode=(0.1,0,0), 
    autopct='%1.1f%%', 
    shadow=True,
    startangle=140)
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.title('Distribution of Age Groups')
plt.show()

# %% [raw]
# More than 50% of customer base are in in age group of 26 - 48 adn ~26% are of age group 18 - 25

# %% [markdown]
# ### 3. Analyze Gender and Location Distribution

# %%
customer_location_gender = df_cust.groupby(['location', 'gender']).size().unstack(fill_value=0)

# Create a stacked bar chart to visualize the distribution of payment types for each occupation
customer_location_gender.plot(kind='bar', stacked=True, figsize=(5, 4))

# Add labels and title
plt.xlabel('Location')
plt.ylabel('Count')
plt.title('Customer Distribution by Location and Gender')

# Show the bar chart
plt.legend(title='Payment Type', bbox_to_anchor=(1, 1))  # Add a legend

# Rotate the x-axis labels for better readability
plt.xticks(rotation=45)

plt.show()

# %% [markdown]
# ### Eplore Credit Scores

# %%
df_cs.head()
# Out:
#    cust_id  credit_score  credit_utilisation  outstanding_debt  \
# 0        1           749            0.585171           19571.0
# 1        2           587            0.107928          161644.0
# 2        3           544            0.854807             513.0
# 3        4           504            0.336938             224.0
# 4        5           708            0.586151           18090.0
#
#    credit_inquiries_last_6_months  credit_limit
# 0                             0.0       40000.0
# 1                             2.0        1250.0
# 2                             4.0        1000.0
# 3                             2.0        1000.0
# 4                             2.0       40000.0

# %%
df_cs.shape
# Out:
# (1004, 6)

# %%
df_cust.shape
# Out:
# (1000, 9)

# %% [markdown]
# 1004 looks like issues with Duplicates

# %%
df_cs["cust_id"].nunique()
# Out:
# 1000

# %%
df_cs.duplicated('cust_id')
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 999     False
# 1000    False
# 1001    False
# 1002    False
# 1003    False
# Length: 1004, dtype: bool

# %%
df_cs[df_cs["cust_id"].duplicated(keep=False)]
# Out:
#      cust_id  credit_score  credit_utilisation  outstanding_debt  \
# 516      517           308                 NaN               NaN
# 517      517           308            0.113860              33.0
# 569      569           344                 NaN               NaN
# 570      569           344            0.112599              37.0
# 607      606           734                 NaN               NaN
# 608      606           734            0.193418            4392.0
# 664      662           442                 NaN               NaN
# 665      662           442            0.856039             266.0
#
#      credit_inquiries_last_6_months  credit_limit
# 516                             NaN           NaN
# 517                             3.0         500.0
# 569                             NaN           NaN
# 570                             0.0         500.0
# 607                             NaN           NaN
# 608                             1.0       40000.0
# 664                             NaN           NaN
# 665                             2.0         500.0

# %%
df_cs_clean_1 = df_cs.drop_duplicates(subset='cust_id', keep="last")
df_cs_clean_1.tail(12)
# Out:
#       cust_id  credit_score  credit_utilisation  outstanding_debt  \
# 992       989           497            0.762646             295.0
# 993       990           772            0.259958           11937.0
# 994       991           709            0.718484           15473.0
# 995       992           555            0.801781             545.0
# 996       993           782            0.477170           20305.0
# 997       994           602            0.605931             796.0
# 998       995           360            0.594345             242.0
# 999       996           564            0.702963             688.0
# 1000      997           774            0.465462           17139.0
# 1001      998           529            0.585856             386.0
# 1002      999           725            0.249670            6973.0
# 1003     1000           775            0.696050           33956.0
#
#       credit_inquiries_last_6_months  credit_limit
# 992                              4.0         750.0
# 993                              2.0       60000.0
# 994                              4.0       40000.0
# 995                              3.0        1250.0
# 996                              2.0       60000.0
# 997                              3.0        1500.0
# 998                              0.0         500.0
# 999                              2.0        1250.0
# 1000                             0.0       60000.0
# 1001                             3.0        1000.0
# 1002                             2.0       40000.0
# 1003                             1.0       60000.0

# %%
df_cs_clean_1.shape
# Out:
# (1000, 6)

# %%
df_cs_clean_1[df_cs_clean_1["cust_id"].duplicated(keep=False)]
# Out:
# Empty DataFrame
# Columns: [cust_id, credit_score, credit_utilisation, outstanding_debt, credit_inquiries_last_6_months, credit_limit]
# Index: []

# %% [markdown]
# Now in the new df no duplicates are available.

# %%
df_cs_clean_1.isnull().sum()
# Out:
# cust_id                            0
# credit_score                       0
# credit_utilisation                 0
# outstanding_debt                   0
# credit_inquiries_last_6_months     0
# credit_limit                      65
# dtype: int64

# %% [markdown]
# Looks like credit_limit has 65 null valve in the df.

# %%
df_cs_clean_1[df_cs_clean_1.credit_limit.isnull()]
# Out:
#      cust_id  credit_score  credit_utilisation  outstanding_debt  \
# 10        11           679            0.557450            9187.0
# 35        36           790            0.112535            4261.0
# 37        38           514            0.296971             238.0
# 45        46           761            0.596041           24234.0
# 64        65           734            0.473715           13631.0
# ..       ...           ...                 ...               ...
# 912      909           479            0.487555             320.0
# 931      928           311            0.832244             316.0
# 948      945           526            0.272734             227.0
# 954      951           513            0.175914             131.0
# 957      954           783            0.867421           46451.0
#
#      credit_inquiries_last_6_months  credit_limit
# 10                              2.0           NaN
# 35                              1.0           NaN
# 37                              2.0           NaN
# 45                              2.0           NaN
# 64                              0.0           NaN
# ..                              ...           ...
# 912                             3.0           NaN
# 931                             2.0           NaN
# 948                             1.0           NaN
# 954                             3.0           NaN
# 957                             0.0           NaN
#
# [65 rows x 6 columns]

# %%
df_cs_clean_1.credit_limit.value_counts()
# Out:
# credit_limit
# 500.0      229
# 60000.0    186
# 40000.0    137
# 1500.0     100
# 1000.0      90
# 750.0       76
# 1250.0      75
# 20000.0     42
# Name: count, dtype: int64

# %%
plt.figure(figsize=(20,5))
plt.scatter(df_cs_clean_1.credit_limit, df_cs_clean_1.credit_score)
plt.title("credit_limit vs credit_score")
plt.xlabel("credit_limit")
plt.ylabel("credit_score")
plt.xticks(range(0,90001,5000))
plt.grid()
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# Credit limit has relationship with the credit_score but the ranges are represent with it.

# %%
bin_ranges = [300, 450, 500, 550, 600, 650, 700, 750, 800]

# Create labels for the bins
bin_labels = [f'{start}-{end-1}' for start, end in zip(bin_ranges, bin_ranges[1:])]

# Use pd.cut to assign data to bins
df_cs_clean_1['credit_score_range'] = pd.cut(df_cs_clean_1['credit_score'], bins=bin_ranges, labels=bin_labels, include_lowest=True, right=False)

# %%
df_cs_clean_1.head()
# Out:
#    cust_id  credit_score  credit_utilisation  outstanding_debt  \
# 0        1           749            0.585171           19571.0
# 1        2           587            0.107928          161644.0
# 2        3           544            0.854807             513.0
# 3        4           504            0.336938             224.0
# 4        5           708            0.586151           18090.0
#
#    credit_inquiries_last_6_months  credit_limit credit_score_range
# 0                             0.0       40000.0            700-749
# 1                             2.0        1250.0            550-599
# 2                             4.0        1000.0            500-549
# 3                             2.0        1000.0            500-549
# 4                             2.0       40000.0            700-749

# %%
df_cs_clean_1[df_cs_clean_1.credit_score_range=="700-749"]
# Out:
#       cust_id  credit_score  credit_utilisation  outstanding_debt  \
# 0           1           749            0.585171           19571.0
# 4           5           708            0.586151           18090.0
# 6           7           747            0.523965           15544.0
# 16         17           702            0.894423           18444.0
# 27         28           729            0.149748            3453.0
# ...       ...           ...                 ...               ...
# 969       966           720            0.203742            6159.0
# 970       967           739            0.845474           23929.0
# 991       988           739            0.435891            9283.0
# 994       991           709            0.718484           15473.0
# 1002      999           725            0.249670            6973.0
#
#       credit_inquiries_last_6_months  credit_limit credit_score_range
# 0                                0.0       40000.0            700-749
# 4                                2.0       40000.0            700-749
# 6                                4.0       40000.0            700-749
# 16                               0.0       40000.0            700-749
# 27                               2.0       40000.0            700-749
# ...                              ...           ...                ...
# 969                              4.0       40000.0            700-749
# 970                              4.0       40000.0            700-749
# 991                              4.0       40000.0            700-749
# 994                              4.0       40000.0            700-749
# 1002                             2.0       40000.0            700-749
#
# [142 rows x 7 columns]

# %%
df_cs_clean_1.groupby("credit_score_range")["credit_limit"].median()
# Out:
# credit_score_range
# 300-449      500.0
# 450-499      750.0
# 500-549     1000.0
# 550-599     1250.0
# 600-649     1500.0
# 650-699    20000.0
# 700-749    40000.0
# 750-799    60000.0
# Name: credit_limit, dtype: float64

# %%
mode_df = df_cs_clean_1.groupby('credit_score_range')['credit_limit'].agg(lambda x: x.mode().iloc[0]).reset_index()
mode_df
# Out:
#   credit_score_range  credit_limit
# 0            300-449         500.0
# 1            450-499         750.0
# 2            500-549        1000.0
# 3            550-599        1250.0
# 4            600-649        1500.0
# 5            650-699       20000.0
# 6            700-749       40000.0
# 7            750-799       60000.0

# %%
df_cs_clean_1[df_cs_clean_1.credit_limit.isnull()].sample(3)
# Out:
#      cust_id  credit_score  credit_utilisation  outstanding_debt  \
# 325      326           599            0.791918             501.0
# 853      850           787            0.293520           11195.0
# 45        46           761            0.596041           24234.0
#
#      credit_inquiries_last_6_months  credit_limit credit_score_range
# 325                             0.0           NaN            550-599
# 853                             3.0           NaN            750-799
# 45                              2.0           NaN            750-799

# %%
df_cs_clean_2 = pd.merge(df_cs_clean_1,mode_df,on="credit_score_range",suffixes=("","_mode"))
df_cs_clean_2
# Out:
#      cust_id  credit_score  credit_utilisation  outstanding_debt  \
# 0          1           749            0.585171           19571.0
# 1          2           587            0.107928          161644.0
# 2          3           544            0.854807             513.0
# 3          4           504            0.336938             224.0
# 4          5           708            0.586151           18090.0
# ..       ...           ...                 ...               ...
# 995      996           564            0.702963             688.0
# 996      997           774            0.465462           17139.0
# 997      998           529            0.585856             386.0
# 998      999           725            0.249670            6973.0
# 999     1000           775            0.696050           33956.0
#
#      credit_inquiries_last_6_months  credit_limit credit_score_range  \
# 0                               0.0       40000.0            700-749
# 1                               2.0        1250.0            550-599
# 2                               4.0        1000.0            500-549
# 3                               2.0        1000.0            500-549
# 4                               2.0       40000.0            700-749
# ..                              ...           ...                ...
# 995                             2.0        1250.0            550-599
# 996                             0.0       60000.0            750-799
# 997                             3.0        1000.0            500-549
# 998                             2.0       40000.0            700-749
# 999                             1.0       60000.0            750-799
#
#      credit_limit_mode
# 0              40000.0
# 1               1250.0
# 2               1000.0
# 3               1000.0
# 4              40000.0
# ..                 ...
# 995             1250.0
# 996            60000.0
# 997             1000.0
# 998            40000.0
# 999            60000.0
#
# [1000 rows x 8 columns]

# %%
df_cs_clean_2[df_cs_clean_2.credit_limit.isnull()].sample(3)
# Out:
#      cust_id  credit_score  credit_utilisation  outstanding_debt  \
# 274      275           798            0.491995           19365.0
# 950      951           513            0.175914             131.0
# 768      769           563            0.865592             898.0
#
#      credit_inquiries_last_6_months  credit_limit credit_score_range  \
# 274                             4.0           NaN            750-799
# 950                             3.0           NaN            500-549
# 768                             3.0           NaN            550-599
#
#      credit_limit_mode
# 274            60000.0
# 950             1000.0
# 768             1250.0

# %% [markdown]
# Still credit_limit is not fill . we can replace the credit_limit mode in the place of credit_limit.

# %%
df_cs_clean_3 = df_cs_clean_2.copy()
df_cs_clean_3["credit_limit"].fillna(df_cs_clean_3["credit_limit_mode"],inplace=True)
df_cs_clean_3.shape
# Out:
# (1000, 8)

# %%
df_cs_clean_3.credit_limit.isnull().sum()
# Out:
# 0

# %%
df_cs_clean_3.isnull().sum()
# Out:
# cust_id                           0
# credit_score                      0
# credit_utilisation                0
# outstanding_debt                  0
# credit_inquiries_last_6_months    0
# credit_limit                      0
# credit_score_range                0
# credit_limit_mode                 0
# dtype: int64

# %%
df_cs_clean_3.loc[[717,301]]
# Out:
#      cust_id  credit_score  credit_utilisation  outstanding_debt  \
# 717      718           481            0.127147              68.0
# 301      302           722            0.608076          122402.0
#
#      credit_inquiries_last_6_months  credit_limit credit_score_range  \
# 717                             0.0         750.0            450-499
# 301                             4.0       40000.0            700-749
#
#      credit_limit_mode
# 717              750.0
# 301            40000.0

# %% [markdown]
# Now that the credit limit is replaced. data is good for analysis for outliers.

# %%
df_cs_clean_3.describe()
# Out:
#            cust_id  credit_score  credit_utilisation  outstanding_debt  \
# count  1000.000000   1000.000000         1000.000000       1000.000000
# mean    500.500000    589.182000            0.498950       9683.597000
# std     288.819436    152.284929            0.233139      25255.893671
# min       1.000000    300.000000            0.103761         33.000000
# 25%     250.750000    460.000000            0.293917        221.000000
# 50%     500.500000    601.500000            0.487422        550.000000
# 75%     750.250000    738.000000            0.697829      11819.500000
# max    1000.000000    799.000000            0.899648     209901.000000
#
#        credit_inquiries_last_6_months  credit_limit  credit_limit_mode
# count                     1000.000000    1000.00000        1000.000000
# mean                         1.955000   19733.75000       19912.500000
# std                          1.414559   24717.43818       24840.914633
# min                          0.000000     500.00000         500.000000
# 25%                          1.000000     750.00000         750.000000
# 50%                          2.000000    1500.00000        1500.000000
# 75%                          3.000000   40000.00000       40000.000000
# max                          4.000000   60000.00000       60000.000000

# %%
sns.boxplot(x=df_cs_clean_3.outstanding_debt)
# Out:
# <Axes: xlabel='outstanding_debt'>

# %% [markdown]
# Now this points are the outliers.

# %%
df_cs_clean_3[df_cs_clean_3.outstanding_debt>df_cs_clean_3.credit_limit]
# Out:
#      cust_id  credit_score  credit_utilisation  outstanding_debt  \
# 1          2           587            0.107928          161644.0
# 19        20           647            0.439132          205014.0
# 25        26           758            0.250811          190838.0
# 38        39           734            0.573023          122758.0
# 93        94           737            0.739948          137058.0
# 204      205           303            0.364360          187849.0
# 271      272           703            0.446886          154568.0
# 301      302           722            0.608076          122402.0
# 330      331           799            0.363420          208898.0
# 350      351           320            0.285081          150860.0
# 446      447           754            0.178394          206191.0
# 544      545           764            0.337769          135112.0
# 636      637           420            0.323984          140063.0
# 646      647           498            0.658087          128818.0
# 698      699           775            0.385100          190717.0
# 723      724           465            0.658173          140008.0
# 725      726           737            0.136048          205404.0
# 730      731           626            0.762245          209901.0
# 766      767           473            0.611750          195004.0
# 862      863           792            0.399555          208406.0
#
#      credit_inquiries_last_6_months  credit_limit credit_score_range  \
# 1                               2.0        1250.0            550-599
# 19                              3.0        1500.0            600-649
# 25                              2.0       60000.0            750-799
# 38                              3.0       40000.0            700-749
# 93                              2.0       40000.0            700-749
# 204                             0.0         500.0            300-449
# 271                             1.0       40000.0            700-749
# 301                             4.0       40000.0            700-749
# 330                             4.0       60000.0            750-799
# 350                             0.0         500.0            300-449
# 446                             2.0       60000.0            750-799
# 544                             2.0       60000.0            750-799
# 636                             4.0         500.0            300-449
# 646                             3.0         750.0            450-499
# 698                             2.0       60000.0            750-799
# 723                             3.0         750.0            450-499
# 725                             4.0       40000.0            700-749
# 730                             2.0        1500.0            600-649
# 766                             1.0         750.0            450-499
# 862                             3.0       60000.0            750-799
#
#      credit_limit_mode
# 1               1250.0
# 19              1500.0
# 25             60000.0
# 38             40000.0
# 93             40000.0
# 204              500.0
# 271            40000.0
# 301            40000.0
# 330            60000.0
# 350              500.0
# 446            60000.0
# 544            60000.0
# 636              500.0
# 646              750.0
# 698            60000.0
# 723              750.0
# 725            40000.0
# 730             1500.0
# 766              750.0
# 862            60000.0

# %% [markdown]
# These are error in the default now. we can replace with the credit_limit as outstanding_limit.

# %%
df_cs_clean_3.loc[df_cs_clean_3['outstanding_debt'] > df_cs_clean_3['credit_limit'], 'outstanding_debt']
# Out:
# 1      161644.0
# 19     205014.0
# 25     190838.0
# 38     122758.0
# 93     137058.0
# 204    187849.0
# 271    154568.0
# 301    122402.0
# 330    208898.0
# 350    150860.0
# 446    206191.0
# 544    135112.0
# 636    140063.0
# 646    128818.0
# 698    190717.0
# 723    140008.0
# 725    205404.0
# 730    209901.0
# 766    195004.0
# 862    208406.0
# Name: outstanding_debt, dtype: float64

# %%
df_cs_clean_3.loc[df_cs_clean_3['outstanding_debt'] > df_cs_clean_3['credit_limit'], 'outstanding_debt'] = df_cs_clean_3['credit_limit']

# %%
df_cs_clean_3[df_cs_clean_3.outstanding_debt>df_cs_clean_3.credit_limit]
# Out:
# Empty DataFrame
# Columns: [cust_id, credit_score, credit_utilisation, outstanding_debt, credit_inquiries_last_6_months, credit_limit, credit_score_range, credit_limit_mode]
# Index: []

# %% [markdown]
# Now the outliers are replace with credit_limit.

# %% [markdown]
# Now check the correlation to this data.

# %%
df_cs_clean_3.head()
# Out:
#    cust_id  credit_score  credit_utilisation  outstanding_debt  \
# 0        1           749            0.585171           19571.0
# 1        2           587            0.107928            1250.0
# 2        3           544            0.854807             513.0
# 3        4           504            0.336938             224.0
# 4        5           708            0.586151           18090.0
#
#    credit_inquiries_last_6_months  credit_limit credit_score_range  \
# 0                             0.0       40000.0            700-749
# 1                             2.0        1250.0            550-599
# 2                             4.0        1000.0            500-549
# 3                             2.0        1000.0            500-549
# 4                             2.0       40000.0            700-749
#
#    credit_limit_mode
# 0            40000.0
# 1             1250.0
# 2             1000.0
# 3             1000.0
# 4            40000.0

# %%
df_cust.head()
# Out:
#    cust_id          name  gender   age location      occupation  \
# 0        1  Dhruv Bansal  Female  51.0     City  Business Owner
# 1        2  Kabir Thakur  Female  47.0     City      Consultant
# 2        3  Kriti Mangal    Male  21.0     City      Freelancer
# 3        4  Sara Dwivedi    Male  24.0    Rural      Freelancer
# 4        5   Aarohi Negi    Male  48.0     City      Consultant
#
#    annual_income marital_status age_group
# 0       358211.0        Married     49-65
# 1        65172.0         Single     26-48
# 2        22378.0        Married     18-25
# 3        33563.0        Married     18-25
# 4        39406.0        Married     26-48

# %%
df_merged = df_cust.merge(df_cs_clean_3, on="cust_id", how="inner")
df_merged.head()
# Out:
#    cust_id          name  gender   age location      occupation  \
# 0        1  Dhruv Bansal  Female  51.0     City  Business Owner
# 1        2  Kabir Thakur  Female  47.0     City      Consultant
# 2        3  Kriti Mangal    Male  21.0     City      Freelancer
# 3        4  Sara Dwivedi    Male  24.0    Rural      Freelancer
# 4        5   Aarohi Negi    Male  48.0     City      Consultant
#
#    annual_income marital_status age_group  credit_score  credit_utilisation  \
# 0       358211.0        Married     49-65           749            0.585171
# 1        65172.0         Single     26-48           587            0.107928
# 2        22378.0        Married     18-25           544            0.854807
# 3        33563.0        Married     18-25           504            0.336938
# 4        39406.0        Married     26-48           708            0.586151
#
#    outstanding_debt  credit_inquiries_last_6_months  credit_limit  \
# 0           19571.0                             0.0       40000.0
# 1            1250.0                             2.0        1250.0
# 2             513.0                             4.0        1000.0
# 3             224.0                             2.0        1000.0
# 4           18090.0                             2.0       40000.0
#
#   credit_score_range  credit_limit_mode
# 0            700-749            40000.0
# 1            550-599             1250.0
# 2            500-549             1000.0
# 3            500-549             1000.0
# 4            700-749            40000.0

# %%
df_merged[["credit_limit","credit_score"]].corr()
# Out:
#               credit_limit  credit_score
# credit_limit      1.000000      0.847952
# credit_score      0.847952      1.000000

# %%
df_merged[["credit_limit","age"]].corr()
# Out:
#               credit_limit       age
# credit_limit      1.000000  0.510993
# age               0.510993  1.000000

# %%
df_merged[["credit_score", "age" ]].corr()
# Out:
#               credit_score       age
# credit_score      1.000000  0.444917
# age               0.444917  1.000000

# %%
numerical_cols = ['credit_score', 'credit_utilisation', 'outstanding_debt', 'credit_limit', 'annual_income','age']

correlation_matrix = df_merged[numerical_cols].corr()
correlation_matrix
# Out:
#                     credit_score  credit_utilisation  outstanding_debt  \
# credit_score            1.000000           -0.070445          0.680654
# credit_utilisation     -0.070445            1.000000          0.192838
# outstanding_debt        0.680654            0.192838          1.000000
# credit_limit            0.847952           -0.080493          0.810581
# annual_income           0.585519           -0.093385          0.563318
# age                     0.444917           -0.027713          0.444301
#
#                     credit_limit  annual_income       age
# credit_score            0.847952       0.585519  0.444917
# credit_utilisation     -0.080493      -0.093385 -0.027713
# outstanding_debt        0.810581       0.563318  0.444301
# credit_limit            1.000000       0.695208  0.510993
# annual_income           0.695208       1.000000  0.622135
# age                     0.510993       0.622135  1.000000

# %%
# Create a heatmap of the correlation matrix
plt.figure(figsize=(5, 3))
sns.heatmap(correlation_matrix, annot=True, fmt=".2f", cmap='coolwarm', linewidths=0.8)
plt.title('Correlation Plot')
plt.show()

# %%
plt.figure(figsize=(5, 4))
sns.scatterplot(x='annual_income', y='credit_score', data=df_merged, alpha=0.7)
plt.title('Scatter Plot of Annual income vs credit score')
plt.xlabel('Annual Income')
plt.ylabel('Credit Score')
plt.show()

# %% [markdown]
# You can see a high correlation between credit limit and credit score (~0.85)
#
# Also credit limit and annual income has a high correlation.
#
# This correlation table can be used for further analysis. It shows if one variable has relationship with the other variable

# %% [markdown]
# Now for the transcation analysis.

# %%
df_trans.head()
# Out:
#    tran_id  cust_id   tran_date  tran_amount  platform   product_category  \
# 0        1      705  2023-01-01           63  Flipkart        Electronics
# 1        2      385  2023-01-01           99   Alibaba  Fashion & Apparel
# 2        3      924  2023-01-01          471   Shopify             Sports
# 3        4      797  2023-01-01           33   Shopify  Fashion & Apparel
# 4        5      482  2023-01-01           68    Amazon  Fashion & Apparel
#
#   payment_type
# 0      Phonepe
# 1  Credit Card
# 2      Phonepe
# 3         Gpay
# 4  Net Banking

# %%
df_trans.isnull().sum()
# Out:
# tran_id                0
# cust_id                0
# tran_date              0
# tran_amount            0
# platform            4941
# product_category       0
# payment_type           0
# dtype: int64

# %% [markdown]
# there are null values in the platform column.

# %%
df_trans[df_trans.platform.isnull()]
# Out:
#         tran_id  cust_id   tran_date  tran_amount platform   product_category  \
# 355         356       58  2023-01-01          237      NaN        Electronics
# 418         419      383  2023-01-01          338      NaN        Electronics
# 607         608      421  2023-01-01          700      NaN        Electronics
# 844         845      945  2023-01-01          493      NaN             Sports
# 912         913      384  2023-01-01           85      NaN  Fashion & Apparel
# ...         ...      ...         ...          ...      ...                ...
# 499579   499580      924  2023-09-05           31      NaN  Fashion & Apparel
# 499646   499647      944  2023-09-05        58445      NaN  Fashion & Apparel
# 499725   499726      620  2023-09-05           15      NaN             Sports
# 499833   499834      616  2023-09-05           97      NaN  Fashion & Apparel
# 499997   499998       57  2023-09-05          224      NaN   Garden & Outdoor
#
#        payment_type
# 355     Net Banking
# 418     Credit Card
# 607         Phonepe
# 844     Credit Card
# 912         Phonepe
# ...             ...
# 499579         Gpay
# 499646      Phonepe
# 499725  Net Banking
# 499833  Credit Card
# 499997      Phonepe
#
# [4941 rows x 7 columns]

# %%
df_trans.platform.value_counts()
# Out:
# platform
# Amazon      151443
# Flipkart    122660
# Alibaba      73584
# Meesho       73271
# Shopify      39416
# Cred         24741
# Ebay          9944
# Name: count, dtype: int64

# %%
df_trans.platform.unique()
# Out:
# array(['Flipkart', 'Alibaba', 'Shopify', 'Amazon', 'Ebay', 'Meesho',
#        'Cred', nan], dtype=object)

# %%
df_trans.platform.mode()
# Out:
# 0    Amazon
# Name: platform, dtype: object

# %%
sns.countplot(y='product_category', hue='platform', data=df_trans)
# Out:
# <Axes: xlabel='count', ylabel='product_category'>

# %% [markdown]
# Mode and from the chart amazon leds in all category transcations. df_trans.platform.mode() this will be the replacing value.

# %%
plat_replace_value = df_trans.platform.mode()[0]
plat_replace_value
# Out:
# 'Amazon'

# %%
df_trans.platform.fillna(plat_replace_value,inplace=True)

# %%
df_trans[df_trans.platform.isnull()]
# Out:
# Empty DataFrame
# Columns: [tran_id, cust_id, tran_date, tran_amount, platform, product_category, payment_type]
# Index: []

# %% [markdown]
# Value has been replaced with plat_replace_value.

# %%
df_trans.isnull().sum()
# Out:
# tran_id             0
# cust_id             0
# tran_date           0
# tran_amount         0
# platform            0
# product_category    0
# payment_type        0
# dtype: int64

# %%
df_trans.describe()
# Out:
#              tran_id        cust_id   tran_amount
# count  500000.000000  500000.000000  500000.00000
# mean   250000.500000     501.400428    3225.20733
# std    144337.711635     288.641924   13098.74276
# min         1.000000       1.000000       0.00000
# 25%    125000.750000     252.000000      64.00000
# 50%    250000.500000     502.000000     141.00000
# 75%    375000.250000     752.000000     397.00000
# max    500000.000000    1000.000000   69999.00000

# %%
df_trans[df_trans.tran_amount.isnull()]
# Out:
# Empty DataFrame
# Columns: [tran_id, cust_id, tran_date, tran_amount, platform, product_category, payment_type]
# Index: []

# %%
df_trans_zero = df_trans[df_trans.tran_amount==0]
df_trans_zero
# Out:
#         tran_id  cust_id   tran_date  tran_amount platform product_category  \
# 120         121      440  2023-01-01            0   Amazon      Electronics
# 141         142      839  2023-01-01            0   Amazon      Electronics
# 517         518      147  2023-01-01            0   Amazon      Electronics
# 533         534      891  2023-01-01            0   Amazon      Electronics
# 586         587      108  2023-01-01            0   Amazon      Electronics
# ...         ...      ...         ...          ...      ...              ...
# 499326   499327      695  2023-09-05            0   Amazon      Electronics
# 499494   499495      295  2023-09-05            0   Amazon      Electronics
# 499708   499709      141  2023-09-05            0   Amazon      Electronics
# 499928   499929        4  2023-09-05            0   Amazon      Electronics
# 499972   499973      224  2023-09-05            0   Amazon      Electronics
#
#        payment_type
# 120     Credit Card
# 141     Credit Card
# 517     Credit Card
# 533     Credit Card
# 586     Credit Card
# ...             ...
# 499326  Credit Card
# 499494  Credit Card
# 499708  Credit Card
# 499928  Credit Card
# 499972  Credit Card
#
# [4734 rows x 7 columns]

# %%
df_trans_zero.head()
# Out:
#      tran_id  cust_id   tran_date  tran_amount platform product_category  \
# 120      121      440  2023-01-01            0   Amazon      Electronics
# 141      142      839  2023-01-01            0   Amazon      Electronics
# 517      518      147  2023-01-01            0   Amazon      Electronics
# 533      534      891  2023-01-01            0   Amazon      Electronics
# 586      587      108  2023-01-01            0   Amazon      Electronics
#
#     payment_type
# 120  Credit Card
# 141  Credit Card
# 517  Credit Card
# 533  Credit Card
# 586  Credit Card

# %%
df_trans_zero.platform.value_counts()
# Out:
# platform
# Amazon    4734
# Name: count, dtype: int64

# %%
df_trans_zero.product_category.value_counts()
# Out:
# product_category
# Electronics    4734
# Name: count, dtype: int64

# %%
df_trans_zero.payment_type.value_counts()
# Out:
# payment_type
# Credit Card    4734
# Name: count, dtype: int64

# %%
df_trans_1 = df_trans[(df_trans.platform=='Amazon')&(df_trans.product_category=="Electronics")&(df_trans.payment_type=="Credit Card")]
df_trans_1.head()
# Out:
#      tran_id  cust_id   tran_date  tran_amount platform product_category  \
# 109      110      887  2023-01-01          635   Amazon      Electronics
# 120      121      440  2023-01-01            0   Amazon      Electronics
# 141      142      839  2023-01-01            0   Amazon      Electronics
# 173      174      676  2023-01-01        60439   Amazon      Electronics
# 190      191      763  2023-01-01          697   Amazon      Electronics
#
#     payment_type
# 109  Credit Card
# 120  Credit Card
# 141  Credit Card
# 173  Credit Card
# 190  Credit Card

# %%
df_amazon_non_zero = df_trans_1[df_trans_1.tran_amount>0]
df_amazon_non_zero
# Out:
#         tran_id  cust_id   tran_date  tran_amount platform product_category  \
# 109         110      887  2023-01-01          635   Amazon      Electronics
# 173         174      676  2023-01-01        60439   Amazon      Electronics
# 190         191      763  2023-01-01          697   Amazon      Electronics
# 263         264      528  2023-01-01          421   Amazon      Electronics
# 311         312      936  2023-01-01          537   Amazon      Electronics
# ...         ...      ...         ...          ...      ...              ...
# 499766   499767      723  2023-09-05          909   Amazon      Electronics
# 499793   499794      586  2023-09-05          304   Amazon      Electronics
# 499812   499813      688  2023-09-05          425   Amazon      Electronics
# 499860   499861      373  2023-09-05          480   Amazon      Electronics
# 499885   499886      520  2023-09-05          643   Amazon      Electronics
#
#        payment_type
# 109     Credit Card
# 173     Credit Card
# 190     Credit Card
# 263     Credit Card
# 311     Credit Card
# ...             ...
# 499766  Credit Card
# 499793  Credit Card
# 499812  Credit Card
# 499860  Credit Card
# 499885  Credit Card
#
# [10903 rows x 7 columns]

# %%
mn_to_rep_amount = df_amazon_non_zero.tran_amount.median()
mn_to_rep_amount
# Out:
# 554.0

# %%
df_trans["tran_amount"].replace(0,mn_to_rep_amount,inplace=True)

# %%
df_trans[df_trans.tran_amount==0]
# Out:
# Empty DataFrame
# Columns: [tran_id, cust_id, tran_date, tran_amount, platform, product_category, payment_type]
# Index: []

# %% [markdown]
# Now the zero are replace with the median of non zero trans of amazon.

# %%
df_trans.describe()
# Out:
#              tran_id        cust_id    tran_amount
# count  500000.000000  500000.000000  500000.000000
# mean   250000.500000     501.400428    3230.452602
# std    144337.711635     288.641924   13097.561071
# min         1.000000       1.000000       2.000000
# 25%    125000.750000     252.000000      66.000000
# 50%    250000.500000     502.000000     146.000000
# 75%    375000.250000     752.000000     413.000000
# max    500000.000000    1000.000000   69999.000000

# %%
sns.histplot(df_trans.tran_amount)
# Out:
# <Axes: xlabel='tran_amount', ylabel='Count'>

# %%
sns.histplot(df_trans.tran_amount, bins=30)
# Out:
# <Axes: xlabel='tran_amount', ylabel='Count'>

# %%
sns.histplot(df_trans[df_trans.tran_amount<10000].tran_amount, bins=30)
# Out:
# <Axes: xlabel='tran_amount', ylabel='Count'>

# %%
Q1 , Q3 = df_trans["tran_amount"].quantile([0.25,0.75])
IQR = Q3 - Q1
upper_limit = Q3 + 2*IQR
lower_limit = Q1 - 2*IQR
upper_limit , lower_limit
# Out:
# (1107.0, -628.0)

# %%
df_trans_outliers =  df_trans[df_trans.tran_amount>=upper_limit]
df_trans_outliers.shape
# Out:
# (25000, 7)

# %%
df_trans_normal =  df_trans[df_trans.tran_amount<upper_limit]
df_trans_normal.shape
# Out:
# (475000, 7)

# %%
df_mean_by_cate = df_trans_normal.groupby("product_category")["tran_amount"].mean()
df_mean_by_cate
# Out:
# product_category
# Beauty & Personal Care     92.167205
# Books                      29.553515
# Electronics               510.172685
# Fashion & Apparel          64.553463
# Garden & Outdoor          125.630277
# Home Decor                302.487561
# Kitchen Appliances        176.773288
# Sports                    269.181631
# Toys & Games               50.333298
# Name: tran_amount, dtype: float64

# %%
df_trans_outliers.head()
# Out:
#      tran_id  cust_id   tran_date  tran_amount  platform  \
# 26        27      380  2023-01-01        61963   Shopify
# 49        50      287  2023-01-01        57869    Amazon
# 94        95      770  2023-01-01        52881      Ebay
# 104      105      549  2023-01-01        58574  Flipkart
# 113      114      790  2023-01-01        51669   Shopify
#
#            product_category payment_type
# 26   Beauty & Personal Care  Credit Card
# 49             Toys & Games         Gpay
# 94       Kitchen Appliances  Credit Card
# 104       Fashion & Apparel         Gpay
# 113      Kitchen Appliances  Credit Card

# %% [markdown]
# Now replace the outliers with the mean by product category.

# %%
df_trans.loc[df_trans_outliers.index,"tran_amount"]=df_trans_outliers["product_category"].map(df_mean_by_cate)

# %%
df_trans.loc[df_trans_outliers.index]
# Out:
#         tran_id  cust_id   tran_date  tran_amount  platform  \
# 26           27      380  2023-01-01    92.167205   Shopify
# 49           50      287  2023-01-01    50.333298    Amazon
# 94           95      770  2023-01-01   176.773288      Ebay
# 104         105      549  2023-01-01    64.553463  Flipkart
# 113         114      790  2023-01-01   176.773288   Shopify
# ...         ...      ...         ...          ...       ...
# 499742   499743      868  2023-09-05    64.553463    Meesho
# 499888   499889      614  2023-09-05    64.553463    Meesho
# 499900   499901      811  2023-09-05   269.181631  Flipkart
# 499966   499967      662  2023-09-05   269.181631    Meesho
# 499996   499997      569  2023-09-05    64.553463    Meesho
#
#               product_category payment_type
# 26      Beauty & Personal Care  Credit Card
# 49                Toys & Games         Gpay
# 94          Kitchen Appliances  Credit Card
# 104          Fashion & Apparel         Gpay
# 113         Kitchen Appliances  Credit Card
# ...                        ...          ...
# 499742       Fashion & Apparel         Gpay
# 499888       Fashion & Apparel  Net Banking
# 499900                  Sports   Debit Card
# 499966                  Sports         Gpay
# 499996       Fashion & Apparel  Net Banking
#
# [25000 rows x 7 columns]

# %%
df_trans.head(6)
# Out:
#    tran_id  cust_id   tran_date  tran_amount  platform   product_category  \
# 0        1      705  2023-01-01         63.0  Flipkart        Electronics
# 1        2      385  2023-01-01         99.0   Alibaba  Fashion & Apparel
# 2        3      924  2023-01-01        471.0   Shopify             Sports
# 3        4      797  2023-01-01         33.0   Shopify  Fashion & Apparel
# 4        5      482  2023-01-01         68.0    Amazon  Fashion & Apparel
# 5        6      527  2023-01-01         38.0   Shopify  Fashion & Apparel
#
#   payment_type
# 0      Phonepe
# 1  Credit Card
# 2      Phonepe
# 3         Gpay
# 4  Net Banking
# 5   Debit Card

# %%
sns.histplot(df_trans.tran_amount,kde=True)
# Out:
# <Axes: xlabel='tran_amount', ylabel='Count'>

# %%
sns.histplot(df_trans.tran_amount,kde=True,bins=20)
# Out:
# <Axes: xlabel='tran_amount', ylabel='Count'>

# %% [markdown]
# Above shows the histogram of transactions after the removal of outliers. You can see that distribution is right skewed. Transaction amount now is less than 1000

# %% [markdown]
# ### Data Visualization: Payment Type Distribution

# %%
sns.countplot(x=df_trans.payment_type, stat='percent',)
# Out:
# <Axes: xlabel='payment_type', ylabel='percent'>

# %% [markdown]
# **Distribution of payment types across age groups**

# %%
df_merged_2 = df_merged.merge(df_trans, on='cust_id', how='inner')
df_merged_2.head(3)
# Out:
#    cust_id          name  gender   age location      occupation  \
# 0        1  Dhruv Bansal  Female  51.0     City  Business Owner
# 1        1  Dhruv Bansal  Female  51.0     City  Business Owner
# 2        1  Dhruv Bansal  Female  51.0     City  Business Owner
#
#    annual_income marital_status age_group  credit_score  ...  \
# 0       358211.0        Married     49-65           749  ...
# 1       358211.0        Married     49-65           749  ...
# 2       358211.0        Married     49-65           749  ...
#
#    credit_inquiries_last_6_months  credit_limit  credit_score_range  \
# 0                             0.0       40000.0             700-749
# 1                             0.0       40000.0             700-749
# 2                             0.0       40000.0             700-749
#
#    credit_limit_mode tran_id   tran_date  tran_amount platform  \
# 0            40000.0    1283  2023-01-01         30.0  Shopify
# 1            40000.0    1382  2023-01-01         96.0   Amazon
# 2            40000.0    1521  2023-01-01         86.0   Meesho
#
#     product_category payment_type
# 0  Fashion & Apparel  Net Banking
# 1             Sports   Debit Card
# 2   Garden & Outdoor         Gpay
#
# [3 rows x 22 columns]

# %%
df_merged_2.shape
# Out:
# (500000, 22)

# %%
plt.figure(figsize=(5, 5))
sns.countplot(x='age_group', hue='payment_type', data=df_merged_2, palette='Set3')
plt.title('Distribution of Payment types across Age groups')
plt.xlabel('Age Group')
plt.ylabel('Count')
plt.xticks(rotation=0)
plt.legend(title='Payment Type', loc='upper right')

plt.show()

# %% [markdown]
# From above analysis, we can see that age group 18-25 has less exposure to credit cards compared to other groups

# %%
fig, (ax1, ax2) = plt.subplots(1,2, figsize=(12,5))

sns.countplot(x='age_group', hue="product_category", data=df_merged_2, ax=ax1)
ax1.set_title("Product Category Count By Age Group")
ax1.set_xlabel("Age Group")
ax1.set_ylabel("Count")
ax1.legend(title="Product Category", loc='upper right')

sns.countplot(x='age_group', hue="platform", data=df_merged_2, ax=ax2)
ax2.set_title("Platform Count By Age Group")
ax2.set_xlabel("Age Group")
ax2.set_ylabel("Count")
ax2.legend(title="Product Category", loc='upper right')

plt.show()

# %% [markdown]
# ### Observations:
#
# 1. Top 3 purchasing categories of customers in age group (18 -25) : Electronics, Fashion & Apparel, Beauty & personal care
# 1. Top platforms : Amazon, Flipkart, Alibaba

# %% [markdown]
# ### Data Visualization: Average Transaction Amount

# %%
# List of categorical columns
cat_cols = ['payment_type', 'platform', 'product_category', 'marital_status', 'age_group']

num_rows = 3
# Create subplots
fig, axes = plt.subplots(num_rows, 2, figsize=(12, 4 * num_rows))

# Flatten the axes array to make it easier to iterate
axes = axes.flatten()

# Create subplots for each categorical column
for i, cat_col in enumerate(cat_cols):
    # Calculate the average annual income for each category
    avg_tran_amount_by_category = df_merged_2.groupby(cat_col)['tran_amount'].mean().reset_index()
    
    # Sort the data by 'annual_income' before plotting
    sorted_data = avg_tran_amount_by_category.sort_values(by='tran_amount', ascending=False)
    
    sns.barplot(x=cat_col, y='tran_amount', data=sorted_data, ci=None, ax=axes[i], palette='tab10')
    axes[i].set_title(f'Average transaction amount by {cat_col}')
    axes[i].set_xlabel(cat_col)
    axes[i].set_ylabel('Average transaction amount')

    # Rotate x-axis labels for better readability
    axes[i].set_xticklabels(axes[i].get_xticklabels(), rotation=45)

# Hide any unused subplots
for i in range(len(cat_cols), len(axes)):
    fig.delaxes(axes[i])
plt.tight_layout()
plt.show()

# %%
df_trans.describe()
# Out:
#              tran_id        cust_id    tran_amount
# count  500000.000000  500000.000000  500000.000000
# mean   250000.500000     501.400428     240.672998
# std    144337.711635     288.641924     241.696597
# min         1.000000       1.000000       2.000000
# 25%    125000.750000     252.000000      64.553463
# 50%    250000.500000     502.000000     133.000000
# 75%    375000.250000     752.000000     349.000000
# max    500000.000000    1000.000000     999.000000

# %% [markdown]
# ### Further Analysis On Age Group
# Let us do further analysis on age group to figure out their average income, credit limit, credit score etc

# %%
age_group_metrics = df_merged.groupby('age_group')[['annual_income', 'credit_limit', 'credit_score']].mean().reset_index()
age_group_metrics
# Out:
#   age_group  annual_income  credit_limit  credit_score
# 0     18-25   35426.796610   1130.081301    484.451220
# 1     26-48  147061.706542  20560.846561    597.569665
# 2     49-65  262390.195531  41699.197861    701.524064

# %%
age_group_metrics.count()
# Out:
# age_group        3
# annual_income    3
# credit_limit     3
# credit_score     3
# dtype: int64

# %%
# Create subplots
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(12, 4))

# Plot 1: Average annual income by age group
sns.barplot(x='age_group', y='annual_income', data=age_group_metrics, palette='tab10', ax=ax1)
ax1.set_title('Average Annual Income by Age Group')
ax1.set_xlabel('Age Group')
ax1.set_ylabel('Average Annual Income')
ax1.tick_params(axis='x', rotation=0)

# Plot 2: Average Max Credit Limit by Age Group
sns.barplot(x='age_group', y='credit_limit', data=age_group_metrics, palette='hls', ax=ax2)
ax2.set_title('Average Credit Limit by Age Group')
ax2.set_xlabel('Age Group')
ax2.set_ylabel('Average Credit Limit')
ax2.tick_params(axis='x', rotation=0)

# Plot 3: Average Credit Score by Age Group
sns.barplot(x='age_group', y='credit_score', data=age_group_metrics, palette='viridis', ax=ax3)
ax3.set_title('Average Credit Score by Age Group')
ax3.set_xlabel('Age Group')
ax3.set_ylabel('Average Credit Score')
ax3.tick_params(axis='x', rotation=0)

plt.tight_layout()
plt.show()

# %% [markdown]
# <h2 align="center", style="color:purple">Finalize Target Market For a Trial Credit Card Launch<h2>

# %% [markdown]
# #### Targeting Untapped market

# %% [markdown]
# 1. People with age group of 18 -25 accounts to ~26% of customer base in the data
# 2. Avg annual income of this group is less than 50k
# 3. They don't have much credit history which is getting reflected in their credit score and credit limit
# 4. Usage of credit cards as payment type is relatively low compared to other groups
# 5. Top 3 most shopping products categories : Electronics, Fashion & Apparel, Beauty & Personal care
